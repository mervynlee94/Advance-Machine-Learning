# %%
import numpy as np

# %%
preds = np.zeros([5, 6])

# %%
for i in range(0,5):
    preds[i] = [1,2,3,4,5,6]

# %%
print(preds)
# Out:
# [[ 1.  2.  3.  4.  5.  6.]
#  [ 1.  2.  3.  4.  5.  6.]
#  [ 1.  2.  3.  4.  5.  6.]
#  [ 1.  2.  3.  4.  5.  6.]
#  [ 1.  2.  3.  4.  5.  6.]]
